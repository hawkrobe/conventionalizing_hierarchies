# %%
import os
import urllib

import pymongo as pm

import matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import seaborn as sns
sns.set_context('poster')
sns.set_style('white')

import numpy as np
from __future__ import division
import scipy.stats as stats
import pandas as pd
import json
import re

from PIL import Image
import base64

# %% [markdown]
# ## set up directory & file hierarchy

# %%
iterationName = 'experiment1'
exp_path = 'experiment1'
analysis_dir = os.getcwd()
data_dir = os.path.abspath(os.path.join(os.getcwd(),'../','data',exp_path))
exp_dir = os.path.abspath(os.path.join(os.getcwd(),'../','experiments',exp_path))

# %% [markdown]
# ## Set up SSH tunnel to server

# %%
# set vars 
sshauth = pd.read_csv('sshauth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
sshpswd = sshauth.values[0][0]

host = 'rxdhawkins.me' ## cocolab ip address
user = 'rxdh'

from sshtunnel import SSHTunnelForwarder
server = SSHTunnelForwarder(
    host,
    ssh_username=user,
    ssh_password=sshpswd,
    remote_bind_address=('127.0.0.1', 27017)
)

server.start()

# %%
auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user

user = 'sketchloop'
pswd = auth.values[0][0]
conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1', server.local_bind_port)
db = conn['basicLevel']
coll = db['artificialLanguage']

# %%
S = coll.find({ '$and': [{'iterationName':'experiment1'}, {'eventType': 'drop'}]}).sort('time')
print(str(S.count()) + ' message records in the database.')
# Out:
# 12506 message records in the database.

# %%
# print unique gameid's
gameids = coll.find({ '$and': [{'iterationName':'experiment1'}, {'eventType': 'postTest_word'}]}).sort('time').distinct('gameid')
print(len(gameids))

# filter out  records that match researcher ID's
jefan = ['A1MMCS8S8CTWKU','A1MMCS8S8CTWKV','A1MMCS8S8CTWKS']
hawkrobe = ['A1BOIDKD33QSDK']
researchers = jefan + hawkrobe
workers = [i for i in coll.find({'iterationName':'experiment1'}).distinct('workerId') if i not in researchers]
print(len(workers))
# Out:
# 127
# 278

# %% [markdown]
# ## Make bonus.csv

# %%
import csv
bonuses = list(coll.aggregate([{'$match' : {'$and' : [{'iterationName' : 'experiment1'}, 
                                                      {'eventType' : 'clickedObj'}, 
                                                      {'correct' : True}]}},
                               {'$group' : {'_id' : '$gameid', 'numCorrect': {'$sum' : 1}}}]))
keys = bonuses[0].keys()
with open('bonuses.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(bonuses)

# %%
participantInfo = list(coll.aggregate([{
    '$match' : {'$and' : [{'iterationName' : 'experiment1'}, 
                          {'eventType' : 'clickedObj'}, 
                           {'correct' : True}]}},{
    '$group' : {'_id' : '$workerId', 
                'assignmentId': {'$first' : "$assignmentId"},
                'gameid': {'$first' : "$gameid"}}}]))
keys = participantInfo[0].keys()
with open('participantInfo.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(participantInfo)
# Out:
# 2018-01-20 16:24:36,627| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:24:41,653| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:24:43,162| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:24:46,690| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:24:51,731| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:24:53,241| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:24:56,757| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:25:01,799| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:25:03,306| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:25:06,822| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:25:11,858| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:25:13,367| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:25:16,885| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:25:21,919| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:25:23,435| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:25:26,936| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:25:31,996| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:25:33,481| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:25:36,995| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:25:42,045| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:25:43,554| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:25:47,056| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:25:52,110| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:25:53,617| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:25:57,121| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:26:02,157| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:26:03,665| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:26:07,184| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:26:12,222| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:26:13,728| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:26:17,238| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:26:22,260| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:26:23,795| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:26:27,321| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:26:32,307| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:26:33,837| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:26:37,359| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:26:42,354| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:26:43,906| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:26:47,428| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:26:52,406| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:26:53,957| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:26:57,482| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:27:02,472| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:27:04,006| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:27:07,532| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:27:12,535| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:27:14,078| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:27:17,591| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:27:22,588| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:27:24,130| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:27:27,650| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:27:32,631| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:27:34,157| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:27:37,683| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:27:42,690| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:27:44,227| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:27:47,753| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:27:52,764| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:27:54,297| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:27:57,824| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:28:02,825| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:28:04,351| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:28:07,869| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:28:12,871| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:28:14,389| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:28:17,902| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:28:22,911| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:28:24,441| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:28:27,953| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:28:32,966| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:28:34,490| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:28:38,008| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:28:43,025| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:28:44,541| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:28:48,065| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:28:53,080| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:28:54,599| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:28:58,121| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:29:03,136| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:29:04,658| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:29:08,182| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:29:13,205| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:29:14,737| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:29:18,255| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:29:23,271| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:29:24,775| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:29:28,328| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:29:33,336| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:29:34,836| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:29:38,376| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:29:43,404| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:29:44,916| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:29:48,444| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:29:53,478| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:29:54,990| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:29:58,513| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:30:03,544| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:30:05,057| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:30:08,576| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:30:13,605| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:30:15,114| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:30:18,623| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:30:23,638| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:30:25,139| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:30:28,656| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:30:33,672| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:30:35,175| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:30:38,714| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:30:43,727| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:30:45,212| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:30:48,765| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:30:53,775| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:30:55,267| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:30:58,807| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:31:03,823| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:31:05,322| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:31:08,857| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:31:13,883| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:31:15,383| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:31:18,907| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:31:23,930| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:31:25,433| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:31:28,950| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:31:33,985| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:31:35,487| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:31:39,004| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:31:44,039| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:31:45,538| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:31:49,058| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:31:54,087| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:31:55,595| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:31:59,119| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:32:04,143| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:32:05,656| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:32:09,185| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:32:14,216| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:32:15,722| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:32:19,228| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:32:24,276| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:32:25,776| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:32:29,261| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:32:34,330| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:32:35,831| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:32:39,316| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:32:44,386| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:32:45,891| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:32:49,371| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:32:54,440| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:32:55,942| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:32:59,440| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:33:04,495| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:33:05,995| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:33:09,481| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:33:14,533| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:33:16,040| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:33:19,522| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:33:24,582| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:33:26,088| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:33:29,556| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:33:34,621| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:33:36,126| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:33:39,602| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:33:44,674| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:33:46,178| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:33:49,660| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:33:54,719| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:33:56,227| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:33:59,709| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:34:04,772| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:34:06,273| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:34:09,748| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:34:14,821| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:34:16,327| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:34:19,789| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:34:24,872| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:34:26,354| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:34:29,831| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:34:34,901| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:34:36,400| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:34:39,895| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:34:44,940| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:34:46,451| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:34:49,938| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:34:54,979| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:34:56,487| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:34:59,993| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:35:05,010| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:35:06,516| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:35:10,037| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:35:15,073| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:35:16,574| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:35:20,092| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:35:25,120| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:35:26,632| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:35:30,151| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:35:35,178| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:35:36,684| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:35:40,201| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:35:45,234| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:35:46,738| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:35:50,263| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:35:55,291| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:35:56,797| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:36:00,317| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:36:05,338| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:36:06,841| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:36:10,365| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:36:15,384| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:36:16,884| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:36:20,403| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:36:25,423| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:36:26,939| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:36:30,442| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:36:35,473| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:36:36,990| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:36:40,499| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:36:45,541| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:36:47,049| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:36:50,571| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:36:55,603| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:36:57,113| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:37:00,638| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:37:05,658| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:37:07,164| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:37:10,688| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:37:15,720| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:37:17,216| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:37:20,741| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:37:25,750| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:37:27,258| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:37:30,794| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:37:35,792| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:37:37,315| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:37:40,835| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:37:45,834| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:37:47,354| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:37:50,892| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:37:55,892| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:37:57,401| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:38:00,942| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:38:05,949| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:38:07,456| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:38:11,002| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:38:16,001| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:38:17,509| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:38:21,042| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:38:26,044| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:38:27,557| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:38:31,093| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:38:36,096| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:38:37,598| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:38:41,134| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:38:46,138| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:38:47,641| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:38:51,166| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:38:56,185| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:38:57,689| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:39:01,204| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:39:06,220| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:39:07,727| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:39:11,239| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:39:16,262| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:39:17,778| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:39:21,292| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:39:26,310| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:39:27,821| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:39:31,338| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:39:36,348| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:39:37,851| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:39:41,384| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:39:46,383| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:39:47,892| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:39:51,425| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:39:56,431| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:39:57,935| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:40:01,467| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:40:06,471| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:40:07,979| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:40:11,505| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:40:16,520| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:40:18,029| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:40:21,541| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:40:26,559| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:40:28,069| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:40:31,582| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:40:36,602| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:40:38,103| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:40:41,612| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:40:46,626| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:40:48,130| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:40:51,642| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:40:56,666| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:40:58,175| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:41:01,684| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:41:06,698| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:41:08,205| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:41:11,713| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:41:16,729| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:41:18,234| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:41:21,738| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:41:26,774| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:41:28,281| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:41:31,772| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:41:36,824| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:41:38,332| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:41:41,834| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:41:46,878| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:41:48,403| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:41:51,898| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:41:56,944| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:41:58,476| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:42:01,969| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:42:07,004| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:42:08,537| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:42:12,038| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:42:17,072| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:42:18,612| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:42:22,102| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:42:27,132| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:42:28,656| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:42:32,169| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:42:37,211| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:42:38,720| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:42:42,242| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:42:47,257| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:42:48,769| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:42:52,295| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:42:57,313| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:42:58,824| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:43:02,344| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:43:07,376| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:43:08,892| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:43:12,408| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:43:17,428| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:43:18,937| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:43:22,455| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:43:27,473| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:43:28,987| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:43:32,498| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:43:37,525| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:43:39,040| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:43:42,551| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:43:47,568| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:43:49,095| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:43:52,594| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:43:57,622| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:43:59,162| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:44:02,645| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:44:07,681| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:44:09,221| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:44:12,711| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:44:17,739| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:44:19,285| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:44:22,765| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:44:27,804| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:44:29,335| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:44:32,834| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:44:37,848| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:44:39,384| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:44:42,878| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:44:47,922| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:44:49,456| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:44:52,957| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:44:57,998| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:44:59,515| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:45:03,034| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:45:08,069| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:45:09,581| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:45:13,099| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:45:18,129| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:45:19,635| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:45:23,150| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:45:28,167| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:45:29,678| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:45:33,194| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:45:38,213| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:45:39,720| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:45:43,238| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:45:48,272| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:45:49,784| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:45:53,300| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:45:58,337| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:45:59,851| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:46:03,378| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:46:08,416| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:46:09,932| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:46:13,455| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:46:18,484| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:46:19,998| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:46:23,510| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:46:28,554| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:46:30,064| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-20 16:46:33,584| ERROR   | Could not establish connection from ('127.0.0.1', 56816) to remote side of the tunnel
# 2018-01-20 16:46:38,619| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-20 16:46:40,128| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# ...
# 2018-01-21 13:10:59,669| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:11:00,390| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:11:00,496| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:11:09,729| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:11:10,443| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:11:10,558| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:11:19,794| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:11:20,510| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:11:20,631| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:11:29,861| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:11:30,568| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:11:30,693| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:11:39,911| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:11:40,630| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:11:40,745| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:11:49,971| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:11:50,695| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:11:50,808| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:12:00,038| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:12:00,759| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:12:00,878| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:12:10,110| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:12:10,816| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:12:10,950| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:12:20,163| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:12:20,883| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:12:21,009| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:12:30,218| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:12:30,937| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:12:31,072| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:12:40,299| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:12:40,999| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:12:41,140| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:12:50,354| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:12:51,057| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:12:51,211| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:13:00,408| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:13:01,112| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:13:01,271| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:13:10,473| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:13:11,174| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:13:11,331| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:13:20,536| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:13:21,226| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:13:21,401| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:13:30,581| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:13:31,276| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:13:31,462| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:13:40,639| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:13:41,337| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:13:41,522| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:13:50,700| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:13:51,397| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:13:51,584| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:14:00,755| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:14:01,456| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:14:01,641| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:14:10,804| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:14:11,505| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:14:11,715| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:14:20,857| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:14:21,569| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:14:21,774| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:14:30,921| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:14:31,631| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:14:31,829| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:14:40,977| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:14:41,685| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:14:41,902| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:14:51,030| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:14:51,736| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:14:51,955| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:15:01,084| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:15:01,794| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:15:02,023| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:15:11,151| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:15:11,867| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:15:12,078| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:15:21,223| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:15:21,930| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:15:22,140| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:15:31,279| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:15:31,989| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:15:32,198| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:15:41,364| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:15:42,045| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:15:42,264| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:15:51,417| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:15:52,109| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:15:52,324| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:16:01,479| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:16:02,160| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:16:02,378| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:16:11,524| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:16:12,223| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:16:12,445| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:16:21,592| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:16:22,276| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:16:22,516| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:16:31,656| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:16:32,350| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:16:32,573| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:16:41,710| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:16:42,425| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:16:42,624| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:16:51,769| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:16:52,480| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:16:52,681| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:17:01,837| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:17:02,543| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:17:02,741| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:17:11,876| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:17:12,594| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:17:12,801| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:17:21,949| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:17:22,658| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:17:22,847| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:17:32,014| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:17:32,716| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:17:32,906| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:17:42,075| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:17:42,785| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:17:42,954| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:17:52,133| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:17:52,849| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:17:53,021| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:18:02,196| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:18:02,902| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:18:03,078| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel
# 2018-01-21 13:18:12,262| ERROR   | Could not establish connection from ('127.0.0.1', 50003) to remote side of the tunnel
# 2018-01-21 13:18:12,968| ERROR   | Could not establish connection from ('127.0.0.1', 51935) to remote side of the tunnel
# 2018-01-21 13:18:13,141| ERROR   | Could not establish connection from ('127.0.0.1', 59796) to remote side of the tunnel

# %% [markdown]
# ## Make data csvs

# %%
valid_gameids = []
for i,g in enumerate(unique_gameids):
    W = coll.find({ '$and': [{'gameid': g}]}).distinct('workerId')
    for w in W:
        if w in workers:
            X = coll.find({ '$and': [{'workerId': w}, {'gameid': g}]}).distinct('trialNum') ## # of trials completed
            eventType = coll.find({ '$and': [{'workerId': w}]}).distinct('eventType')
            print i, w[:4], len(X), str(eventType[0])
            if (str(eventType[0])=='clickedObj') & (len(X)==32):
                valid_gameids.append(g)
print '   ===========   '

## filter if the pair cheated by writing words or using other symbols
cheaty = ['8155-e46a25a3-9259-4b76-80e9-5bd79b6bdd97','6224-ab96ed5c-2a98-477c-aae2-7398b9e5b237',\
         '5595-a00b8109-1910-43c4-9f14-00eb4945ac70','1697-7ab5b295-fae8-4f62-8cbd-72aa0e23b10e']
motor = ['2829-820b338d-5720-4964-bd22-8ba38329569d'] # this person made multiples in several of their sketches, and appeared to suffer from strong tremors
valid_gameids = [i for i in valid_gameids if i not in cheaty]
valid_gameids = [i for i in valid_gameids if i not in motor]

print str(len(valid_gameids)) + ' valid gameIDs (# complete games).'

df = pd.DataFrame([valid_gameids])
df = df.transpose()
df.columns=['valid_gameids']
df.to_csv('valid_gameids_pilot2.csv')

# %%
TrialNum = []
GameID = []
Condition = []
Target = []
Distractor1 = []
Distractor2 = []
Distractor3 = []
Outcome = []
Response = []
numStrokes = []
drawDuration = [] # in seconds
svgStringLength = [] # sum of svg string for whole sketch
svgStringLengthPerStroke = [] # svg string length per stroke
numCurvesPerSketch = [] # number of curve segments per sketch
numCurvesPerStroke = [] # mean number of curve segments per stroke
svgStringStd = [] # std of svg string length across strokes for this sketch
Outcome = []
Pose = []
Svg = []

for g in valid_gameids:
    print 'Analyzing game: ', g

    X = coll.find({ '$and': [{'gameid': g}, {'eventType': 'clickedObj'}]}).sort('time')
    Y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}]}).sort('time')

    for t in X:
        targetname = t['intendedName']
        distractors = [t['object2Name'],t['object3Name'],t['object4Name']]
        full_list = [t['intendedName'],t['object2Name'],t['object3Name'],t['object4Name']] 
        y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}, {'trialNum': t['trialNum']}]}).sort('time')
        ns = y.count()
        numStrokes.append(ns)
        drawDuration.append((y.__getitem__(ns-1)['time'] - y.__getitem__(0)['time'])/1000) # in seconds        
        ls = [len(_y['svgData']) for _y in y]
        svgStringLength.append(reduce(lambda x, y: x + y, ls))
        y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}, {'trialNum': t['trialNum']}]}).sort('time')
        num_curves = [len([m.start() for m in re.finditer('c', _y['svgData'])]) for _y in y]
        y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}, {'trialNum': t['trialNum']}]}).sort('time')        
        _svg = []
        for _y in y:
            _svg.append(_y['svgData'])
        Svg.append(_svg)
        numCurvesPerSketch.append(reduce(lambda x, y: x + y, num_curves))
        numCurvesPerStroke.append(reduce(lambda x, y: x + y, num_curves)/ns)
        svgStringLengthPerStroke.append(reduce(lambda x, y: x + y, ls)/ns)
        svgStringStd.append(np.std(ls))
    #     ## aggregate game metadata
        TrialNum.append(t['trialNum'])
        GameID.append(t['gameid'])        
        Target.append(targetname)
        Condition.append(t['condition'])
        Response.append(t['clickedName'])
        Outcome.append(t['correct'])
        Distractor1.append(distractors[0])
        Distractor2.append(distractors[1])
        Distractor3.append(distractors[2])
        Pose.append(t['pose'])

# %%
iteration = ['pilot2']*len(GameID)

_D = pd.DataFrame([GameID,TrialNum,Condition, Target, drawDuration, Outcome, Response, numStrokes, \
                  svgStringLength, svgStringLengthPerStroke, svgStringStd, Distractor1, Distractor2, \
                   Distractor3, Pose, iteration, Svg]) \

D =_D.transpose()
D.columns = ['gameID','trialNum','condition', 'target', 'drawDuration','outcome', 'response', \
             'numStrokes', 'svgStringLength', 'svgStringLengthPerStroke', 'svgStringStd', \
            'Distractor1', 'Distractor2', 'Distractor3', 'pose', 'iteration', 'svg']

# %%
## add png to D dataframe
png = []
for g in valid_gameids:
    X = coll.find({ '$and': [{'gameid': g}, {'eventType': 'clickedObj'}]}).sort('time')
    Y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}]}).sort('time')
    # print out sketches from all trials from this game
    for t in X: 
        png.append(t['pngString'])
D = D.assign(png=pd.Series(png).values)

iteration = ['pilot2']*len(D['gameID'].values)
D = D.assign(iteration=pd.Series(iteration).values)

# %%
## add another cost-related dependent measure: mean pixel intensity (amount of ink spilled) -- to handle
## some weird glitches in the num stroke count
mean_intensity = []
imsize = 100
numpix = imsize**2
thresh = 250

for i,_d in D.iterrows():
    imgData = _d['png']
    filestr = base64.b64decode(imgData)
    fname = os.path.join('sketch.png')
    with open(fname, "wb") as fh:
        fh.write(imgData.decode('base64'))
    im = Image.open(fname).resize((imsize,imsize))
    _im = np.array(im)
    mean_intensity.append(len(np.where(_im[:,:,3].flatten()>thresh)[0])/numpix)

# %%
# add mean_intensity to the main D dataframe 
### btw: mean_intensity and numStrokes is about 0.43 spearman correlated.
D = D.assign(mean_intensity=pd.Series(mean_intensity).values)
print stats.spearmanr(D['mean_intensity'].values,D['numStrokes'].values)

category = [h.objcat[t] for t in D.target.values]
D = D.assign(category=pd.Series(category).values)

# %%
# save D out as group_data.csv 
D.to_csv(os.path.join(analysis_dir,'sketchpad_basic_pilot2_group_data.csv'))

# %%
# read group data csv in as D
D = pd.read_csv(os.path.join(analysis_dir,'sketchpad_basic_pilot2_group_data.csv'))

# %%
# get summary statistics
all_games = np.unique(D['gameID'])
further_strokes = []
closer_strokes = []
further_svgLength = []
closer_svgLength = []
further_svgStd = []
closer_svgStd = []
further_svgLengthPS = []
closer_svgLengthPS = []
further_drawDuration = []
closer_drawDuration = []
further_accuracy = []
closer_accuracy = []
closer_meanintensity = []
further_meanintensity = []
for game in all_games:    
    further_strokes.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['numStrokes'].mean())
    closer_strokes.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['numStrokes'].mean())
    further_svgLength.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['svgStringLength'].mean())
    closer_svgLength.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['svgStringLength'].mean())
    further_svgStd.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['svgStringStd'].mean())
    closer_svgStd.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['svgStringStd'].mean())    
    further_svgLengthPS.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['svgStringLengthPerStroke'].mean())
    closer_svgLengthPS.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['svgStringLengthPerStroke'].mean())
    further_drawDuration.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['drawDuration'].mean())
    closer_drawDuration.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['drawDuration'].mean())
    further_accuracy.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['outcome'].mean())
    closer_accuracy.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['outcome'].mean())
    closer_meanintensity.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['mean_intensity'].mean())    
    further_meanintensity.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['mean_intensity'].mean())        
    
further_strokes, closer_strokes, further_svgLength, closer_svgLength, \
further_svgStd, closer_svgStd, further_svgLengthPS, closer_svgLengthPS, \
further_drawDuration, closer_drawDuration, further_accuracy, closer_accuracy, \
closer_meanintensity,further_meanintensity = map(np.array, \
[further_strokes, closer_strokes, further_svgLength, closer_svgLength,\
 further_svgStd, closer_svgStd, further_svgLengthPS, closer_svgLengthPS, \
further_drawDuration, closer_drawDuration, further_accuracy, closer_accuracy, \
closer_meanintensity, further_meanintensity])

# %%
def trim_outliers(x):
    mu = np.mean(x)
    sd = np.std(x)
    thresh = mu + sd*3
    y = [i for i in x if i<thresh]
    return y

def bootstrap(w,nIter=50000):
    boot = []
    for i in np.arange(nIter):
        boot.append(np.mean(np.random.choice(w,len(w),replace=True)))
    boot = np.array(boot) 
    p = sum(boot<0)/len(boot)*2
    lb = np.percentile(boot,2.5)
    ub = np.percentile(boot,97.5)
    print 'p = ' + str(sum(boot<0)/len(boot)*2)
    return boot, p, lb, ub

print D.groupby('condition')['numStrokes'].mean()
print D.groupby('condition')['mean_intensity'].mean()
print D.groupby('condition')['drawDuration'].mean()
print D.groupby('condition')['outcome'].mean()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
ax = sns.barplot(data=D,x='condition',y='numStrokes')
plt.ylabel('num strokes')
plt.subplot(1,4,2)
sns.barplot(data=D,x='condition',y='mean_intensity')
plt.ylabel('mean pixel intensity')
plt.subplot(1,4,3)
sns.barplot(data=D,x='condition',y='outcome')
plt.ylabel('accuracy')
plt.ylim([0,1.01])
plt.subplot(1,4,4)
sns.barplot(data=D,x='condition',y='drawDuration')
plt.ylabel('draw duration (s)')
plt.tight_layout()
plt.savefig('./plots/sketchpad_basic_pilot2_taskperformance.pdf')

# %%
valid_gameids

# %%
## bootstrapped CI's on main task performance measures
boot, p, lb, ub = bootstrap(closer_strokes - further_strokes)
print p,lb,ub

boot, p, lb, ub = bootstrap(closer_meanintensity - further_meanintensity)
print p,lb,ub

boot, p, lb, ub = bootstrap(closer_drawDuration - further_drawDuration)
print p,lb,ub

# %%
fig = plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
lb = 0
ub = 24
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_strokes,further_strokes,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.title('number of strokes')
plt.xlabel('closer')
plt.ylabel('further')
plt.subplot(2,2,2)
lb = 0
ub = 3000
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_svgLength,further_svgLength,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.tight_layout()
plt.title('svg string length')
plt.xlabel('closer')
plt.ylabel('further')
plt.subplot(2,2,3)
lb = 0
ub = 300
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_svgStd,further_svgStd,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.title('stroke variability')
plt.xlabel('closer')
plt.ylabel('further')
plt.subplot(2,2,4)
lb = 0
ub = 300
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_svgLengthPS,further_svgLengthPS,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.tight_layout()
plt.title('svg length per stroke')
plt.xlabel('closer')
plt.ylabel('further')
save_out = 1
if not os.path.exists('plots'):
    os.makedirs('plots')
if save_out:
    save('plots/svg_summary_scatter_{}'.format(iterationName), ext='pdf', close=False, verbose=True)

# %%
fig = plt.figure(figsize=(8,4))
lb = 0
ub = 1.03
plt.subplot(1,2,1)
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_accuracy,further_accuracy,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.title('accuracy')
plt.xlabel('closer')
plt.ylabel('further')
plt.subplot(1,2,2)
lb = 0
ub = 36
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_drawDuration,further_drawDuration,64,(0.75,0.3,0.2))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.title('draw duration')
plt.xlabel('closer')
plt.ylabel('further')
plt.tight_layout()
save_out = 1
if save_out:
    save('plots/performance_summary_scatter_{}'.format(iterationName), ext='pdf', close=False, verbose=True)

# %%
def get_canonical(category):    
    stimFile = os.path.join(exp_dir,'stimList_subord.js')
    with open(stimFile) as f:
        stimList = json.load(f)    
    allviews = [i['filename'] for i in stimList if i['basic']==category]
    canonical = [a for a in allviews if a[-8:]=='0035.png']    
    return canonical

def get_actual_pose(subordinate,pose):
    stimFile = os.path.join(exp_dir,'stimList_subord.js')
    with open(stimFile) as f:
        stimList = json.load(f)
    inpose = [i['filename'] for i in stimList if (i['subordinate']==subordinate) and (i['pose']==pose)]
    return inpose
    
def get_subord_names(category):
    full_names = get_canonical(category)    
    return [c.split('_')[2] for c in full_names]

def get_basic_names(subordinate):
    stimFile = os.path.join(exp_dir,'stimList_subord.js')
    with open(stimFile) as f:
        stimList = json.load(f)   
    allviews = [i['filename'] for i in stimList if i['subordinate']==subordinate]
    canonical = [a for a in allviews if a[-8:]=='0035.png']      
    return canonical[0].split('_')[0]

def build_url_from_category(category):
    full_names = get_canonical(category)
    url_prefix = 'https://s3.amazonaws.com/sketchloop-images-subord/'
    urls = []
    for f in full_names:
        urls.append(url_prefix + f)
    return urls

def build_url_from_filenames(filenames):
    url_prefix = 'https://s3.amazonaws.com/sketchloop-images-subord/'
    urls = []
    for f in filenames:
        urls.append(url_prefix + f)
    return urls

def plot_from_url(URL):
    file = cStringIO.StringIO(urllib.urlopen(URL).read())
    img = Image.open(file)    

def plot_gallery(category):
    import matplotlib.pyplot as plt
    import matplotlib.gridspec as gridspec

    plt.figure(figsize = (8,8))
    gs1 = gridspec.GridSpec(8, 8)
    gs1.update(wspace=0.025, hspace=0.05)

    url_prefix = 'https://s3.amazonaws.com/sketchloop-images-subord/'
    for (i,c) in enumerate(category):
        URL = url_prefix + c
        file = cStringIO.StringIO(urllib.urlopen(URL).read())
        img = Image.open(file)
        p = plt.subplot(3,3,i+1)
        plt.imshow(img)
        p.get_xaxis().set_ticklabels([])
        p.get_yaxis().set_ticklabels([])
        p.get_xaxis().set_ticks([])
        p.get_yaxis().set_ticks([])
        p.set_aspect('equal')
        subord = c.split('_')[2]
        plt.title(subord)
    plt.tight_layout()

# %%
## print out sketches with target & distractors from this game
import traceback
backup_path_images = '/Users/judithfan/Dropbox/stimuli_repository/subordinate_allrotations_6_minified'

_valid_gameids = valid_gameids[:3]

## get list of all incorrect sketch path names
incorrect_trial_paths = []

run_this = 0
if run_this:
#     all_games = click_files
    for g in valid_gameids:
        print 'Printing out sketches from game: ' + g
        _D = D[(D.gameID==g)]
        _D = _D.sort_values(by=['target'])
        _i = 1
        textsize=12
        fig = plt.figure(figsize=(16,6))        
        for i,_d in _D.iterrows():
            imgData = _d['png']
            filestr = base64.b64decode(imgData)
            target_sketch_dir = os.path.join(analysis_dir,'sketches_pilot2','sketch')
            if not os.path.exists(target_sketch_dir):
                os.makedirs(target_sketch_dir)
            fname = os.path.join(target_sketch_dir,'gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) + '.png')
            with open(fname, "wb") as fh:
                fh.write(imgData.decode('base64'))
            textsize = 16
            # first plot the target
            im = Image.open(fname)
            p = plt.subplot(2,4,1)
            plt.imshow(im)
            sns.set_style('white')
            k = p.get_xaxis().set_ticklabels([])
            k = p.get_yaxis().set_ticklabels([])
            k = p.get_xaxis().set_ticks([])
            k = p.get_yaxis().set_ticks([])        
            targetname = _d['target']
            distractors = [_d['Distractor1'],_d['Distractor2'],_d['Distractor3']]
            full_list = [_d['target'],_d['Distractor1'],_d['Distractor2'],_d['Distractor3']] 
            outcome = _d['outcome']
            if _d['outcome']==0:
                incorrect_trial_paths.append('gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) + '_' + _d['target'] + '.png')            
                        
            response = _d['response']        
            if outcome == 1:
                sides = ['bottom','top','right','left']
                for s in sides:
                    p.spines[s].set_color((0.4,0.8,0.4))
                    p.spines[s].set_linewidth(4)                               
            else:
                sides = ['bottom','top','right','left']
                for s in sides:
                    p.spines[s].set_color((0.9,0.2,0.2))
                    p.spines[s].set_linewidth(4)                      
            plt.title(targetname,fontsize=textsize)
            plt.ylabel('v:' + response,fontsize=textsize-2)        
        
            # fig = plt.figure(figsize=(8,3))
            for (i,d) in enumerate(full_list):
                if os.path.exists(backup_path_images):
                    if hasattr(t, 'pose'):
                        fn = os.path.join(backup_path_images,get_actual_pose(d,pose)[0])
                    else:
                        fn = os.path.join(backup_path_images,get_actual_pose(d,35)[0])
                else:
                    if hasattr(t, 'pose'):
                        pose = t['pose']
                        URL = build_url_from_filenames(get_actual_pose(d,pose)[0])
                    else:
                        URL = full_dict[d]
                    fn = cStringIO.StringIO(urllib.urlopen(URL).read())
                img = Image.open(fn)
                p = plt.subplot(2,4,i+5)
                plt.imshow(img)
                p.get_xaxis().set_ticklabels([])
                p.get_yaxis().set_ticklabels([])
                p.get_xaxis().set_ticks([])
                p.get_yaxis().set_ticks([])
                p.set_aspect('equal')   
                plt.title(d)

            sketch_dir = os.path.join(analysis_dir,'sketches_pilot2','full_display')
            if not os.path.exists(sketch_dir):
                os.makedirs(os.path.join(analysis_dir,'sketches_pilot2','full_display'))
            filepath = os.path.join(sketch_dir,'gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']))
            save(filepath, ext='png', close=True, verbose=False)

# %%
## save out number of incorrect trial paths
print "Number of incorrect trial paths: {}".format(str(len(incorrect_trial_paths)))
with open('incorrect_trial_paths_pilot2.txt', 'w') as f:
    for path in incorrect_trial_paths:
        f.write(path + '\n')

# %% [markdown]
# ### Print out sketches in separate folders

# %%
## print out sketches with target & distractors from this game in separate folders
import traceback
backup_path_images = '/Users/judithfan/Dropbox/stimuli_repository/subordinate_allrotations_6_minified'

_valid_gameids = valid_gameids[:3]

target_sketch_dir = os.path.join(analysis_dir,'sketches_pilot2','sketch')
target_3D_dir = os.path.join(analysis_dir,'sketches_pilot2','target')
distractor1_3D_dir = os.path.join(analysis_dir,'sketches_pilot2','distractor1')
distractor2_3D_dir = os.path.join(analysis_dir,'sketches_pilot2','distractor2')
distractor3_3D_dir = os.path.join(analysis_dir,'sketches_pilot2','distractor3')
out_paths = [target_3D_dir,distractor1_3D_dir,distractor2_3D_dir,distractor3_3D_dir]


if not os.path.exists(target_3D_dir):
    os.makedirs(os.path.join(analysis_dir,'sketches_pilot2','target'))
    os.makedirs(os.path.join(analysis_dir,'sketches_pilot2','distractor1'))
    os.makedirs(os.path.join(analysis_dir,'sketches_pilot2','distractor2'))
    os.makedirs(os.path.join(analysis_dir,'sketches_pilot2','distractor3'))
    os.makedirs(os.path.join(analysis_dir,'sketches_pilot2','sketch'))    

run_this = 1
if run_this:
    for g in valid_gameids:
        print 'Printing out sketches from game: ' + g
        _D = D[(D.gameID==g)]
        _D = _D.sort_values(by=['target'])
        _i = 1
        textsize=12
        fig = plt.figure(figsize=(16,6))        
        for i,_d in _D.iterrows():
            imgData = _d['png']
            filestr = base64.b64decode(imgData)
            if not os.path.exists(target_sketch_dir):
                os.makedirs(target_sketch_dir)
            fname = os.path.join(target_sketch_dir,'gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) + '.png')
            with open(fname, "wb") as fh:
                fh.write(imgData.decode('base64'))
            im = Image.open(fname)
            im.save(fname)

            targetname = _d['target']
            distractors = [_d['Distractor1'],_d['Distractor2'],_d['Distractor3']]
            full_list = [_d['target'],_d['Distractor1'],_d['Distractor2'],_d['Distractor3']]         
            
            for (i,d) in enumerate(full_list):
                if os.path.exists(backup_path_images):
                    if hasattr(t, 'pose'):
                        fn = os.path.join(backup_path_images,get_actual_pose(d,pose)[0])
                    else:
                        fn = os.path.join(backup_path_images,get_actual_pose(d,35)[0])
                else:
                    if hasattr(t, 'pose'):
                        pose = _d['pose']
                        URL = build_url_from_filenames(get_actual_pose(d,pose)[0])
                    else:
                        URL = full_dict[d]
                    fn = cStringIO.StringIO(urllib.urlopen(URL).read())
                fig = plt.figure(figsize=(8,8))                    
                im = Image.open(fn)
                im = im.resize((256,256), Image.ANTIALIAS).convert('RGB')                                
                out_dirs = [target_3D_dir,distractor1_3D_dir,distractor2_3D_dir,distractor3_3D_dir]                
                out_path = os.path.join(out_dirs[i],'gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) + '_' + d + '.png')
                im.save(out_path)

# %%
D = pd.read_csv('/data/jefan/sketchpad_basic_fixedpose96/sketchpad_basic_pilot2_group_data.csv')
D.shape

# %% [markdown]
# ## Load in data again to prep for model comparison

# %%
D = pd.read_csv(os.path.join(analysis_dir,'sketchpad_basic_pilot2_group_data.csv'))

# filter out incorrect and invalid trials as well
incorrects = pd.read_csv('./incorrect_trial_paths_pilot2.txt',header=None)[0].values
invalids = pd.read_csv('./invalid_trial_paths_pilot2.txt',header=None)[0].values
fname = []
for i,_d in D.iterrows():
    fname.append('gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) + '_' + _d['target'] +'.png')    
D = D.assign(fname=pd.Series(fname).values)  

fname_no_target = []
for i,_d in D.iterrows():
    fname_no_target.append('gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) +'.png')    
D = D.assign(fname_no_target=pd.Series(fname_no_target).values) 

print np.shape(D)
D = D[~D['fname'].isin(incorrects)]
print np.shape(D)
D = D[~D['fname_no_target'].isin(invalids)]
print np.shape(D)

print str(np.shape(D)[0]) + ' records in merged dataframe'

# %% [markdown]
# ### Visualize distance distributions

# %%
path_to_dists = './RSA/refModule/json/strict-similarity-pragmatics-fixedpose-augmented-splitbycontext_conv4_2.json'
_dists = pd.read_json(path_to_dists)
dists = _dists.transpose()
x = _dists.columns.values
y = [i.split('_')[-1] for i in x]
lookup_table = dict(zip(y,x))
reverse_lookup = dict(zip(x,y))

# %%
# sketch_label = [('trial_' + str(i) + '_' + str(j)) for i,j in zip(D['trialNum'].values,D['target'].values)]
sketch_label = [(i[-12:] + '_' + str(j)) for i,j in zip(D['gameID'].values,D['trialNum'].values)]
D = D.assign(sketch_label=pd.Series(sketch_label).values)

# %%
# add class label
category = []
classes = ['bird','car','chair','dog']
for i,d in D.iterrows():
    category.append(h.objcat[d['target']])
D = D.assign(category=pd.Series(category).values)

# %%
dT = []
dD1 = []
dD2 = []
dD3 = []
for i, _d in D.iterrows():
    sketch = _d['sketch_label']
    pose = int(_d['pose'])
    target = lookup_table[_d['target']]
    distractor1 = lookup_table[_d['Distractor1']]
    distractor2 = lookup_table[_d['Distractor2']]
    distractor3 = lookup_table[_d['Distractor3']]
    dT.append(dists[sketch][target])
    dD1.append(dists[sketch][distractor1])
    dD2.append(dists[sketch][distractor2])
    dD3.append(dists[sketch][distractor3])

# %%
D = D.assign(dT=pd.Series(dT).values)
D = D.assign(dD1=pd.Series(dD1).values)
D = D.assign(dD2=pd.Series(dD2).values)
D = D.assign(dD3=pd.Series(dD3).values)

# %%
# filter out training examples
# test_examples = pd.read_csv('./pilot2_augmented2_test_examples.txt',header=None)[0].values
# test_examples = [i.split('.')[0] + '.png' for i in test_examples]

# %%
sns.set_context('talk')
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
_D = D[(D.condition=='closer') & (D['fname'].isin(test_examples))]
distractor_dists = np.hstack((_D.dD1.values,_D.dD2.values,_D.dD3.values))
sns.kdeplot(distractor_dists, shade=True, color=(0.3,0.3,0.3),label='distractors')
sns.kdeplot(_D.dT.values, shade=True, color=(0.9,0.7,0.1),label='target')
plt.ylim([0,7])
plt.xlim([-1,1])
plt.xlabel('distance')
plt.title('close')

plt.subplot(1,2,2)
_D = D[(D.condition=='further') & (D['fname'].isin(test_examples))]
distractor_dists = np.hstack((_D.dD1.values,_D.dD2.values,_D.dD3.values))
sns.kdeplot(distractor_dists, shade=True, color=(0.3,0.3,0.3),label='distractors')
sns.kdeplot(_D.dT.values, shade=True, color=(0.9,0.7,0.1),label='target')
plt.ylim([0,7])
plt.xlim([-1,1])
plt.xlabel('distance')
plt.title('far')

plt.suptitle('fixedpose - augmented - splitbycontext - test')

# %%
sns.set_context('talk')
plt.figure(figsize=(12,12))
for i,cl in enumerate(classes):
    plt.subplot(2,2,i+1)
    _D = D[(D['fname'].isin(test_examples)) & (D['category']==cl)]
    distractor_dists = np.hstack((_D.dD1.values,_D.dD2.values,_D.dD3.values))
    sns.kdeplot(distractor_dists, shade=True, color=(0.3,0.3,0.3),label='distractors')
    sns.kdeplot(_D.dT.values, shade=True, color=(0.9,0.7,0.1),label='target')
    plt.ylim([0,7])
    plt.xlim([-1,1])
    if i>1:
        plt.xlabel('distance')
    plt.title('{}'.format(cl))

# %% [markdown]
# ### Preprocessing to make bdaInput csv

# %%
## make sure that the CLOSE training examples are filtered out
# filter out training examples
test_examples = pd.read_csv('./pilot2_augmented_splitbycontext_test_examples.txt',header=None)[0].values
test_examples = [i.split('.')[0] + '.png' for i in test_examples]
# close_test_examples = test_examples
# far_all_examples = list(D[D.condition=='further'].fname.values)
# keep_examples = close_test_examples #+ far_all_examples
keep_examples = test_examples
D0 = D[D['fname'].isin(keep_examples)]
print('Shape of D0: {}'.format(D0.shape))

# %%
_sketchLabel = []
_Condition = []
_Target = []
_Distractor1 = []
_Distractor2 = []
_Distractor3 = []
for i, _d in D0.iterrows():
    _sketchLabel.append(_d['sketch_label'])
    _Condition.append(_d['condition'])    
    _Target.append(lookup_table[_d['target']])
    distractor1 = lookup_table[_d['Distractor1']]
    distractor2 = lookup_table[_d['Distractor2']]
    distractor3 = lookup_table[_d['Distractor3']]
    d_list = sorted([distractor1, distractor2, distractor3])
    _Distractor1.append(d_list[0])
    _Distractor2.append(d_list[1])    
    _Distractor3.append(d_list[2])

# %%
D2 = pd.DataFrame([_Condition,_sketchLabel,_Target,_Distractor1,_Distractor2,_Distractor3])
D2 = D2.transpose()
D2.columns = ['condition','sketchLabel','Target','Distractor1','Distractor2','Distractor3']
D2.to_csv('./RSA/bdaInput/sketchData_fixedPose_splitbycontext_augmented2_pilot2.csv')

# %%
D2.shape

# %% [markdown]
# ## Model comparison

# %%
def sumlogprob(a,b):
    if (a > b):
        return a + np.log1p(np.exp(b-a))
    else:
        return b + np.log1p(np.exp(a-b))

# %%
which_feat = 'fixedpose_aug2_alldata'

if which_feat == 'varypose_nonaug':
    P = pd.read_csv('./RSA/bdaOutput/testingParams_alldata.csv')
elif which_feat == 'fixedpose_nonaug_closeonly':
    P = pd.read_csv('./RSA/bdaOutput/testingParams_closeonly_fixedpose.csv')
elif which_feat == 'fixedpose_aug_closeonly':
    P = pd.read_csv('./RSA/bdaOutput/testingParams_closeonly_fixedpose_augmented.csv')
elif which_feat == 'fixedpose_aug2_alldata':
    P = pd.read_csv('./RSA/bdaOutput/testingParams_testdata_fixedpose_augmented2.csv')
    
# filter out rows where posterior probability is -Infinity
# P = P[P.posteriorProb!='-Infinity']
print np.shape(P)

X = P.groupby(['similarityMetric', 'speakerModel'])['logLikelihood']
Y = X.apply(lambda x: reduce(sumlogprob,x) - np.log(len(x)))
Y = pd.DataFrame(Y)

sns.set_context('poster')
colors = sns.color_palette("Paired")
fig = plt.figure(figsize=(26,8))
seq = [('strict-mid-pragmatics-augmented2','S0'),('strict-mid-pragmatics-augmented2','S1'),('nonstrict-high-sketchy','S0'),('nonstrict-high-sketchy','S1')]
sns.barplot(data=Y.transpose(),palette=colors, order = seq)
# plt.ylim([-1400,-600])
plt.ylabel('log likelihood')
plt.title('model comparison: all test data',fontsize=24)
plt.show()

# %%
Y

# %%
# P = pd.read_csv('./RSA/bdaOutput/testingParams_testdata_fixedpose.csv')
# # filter out rows where posterior probability is -Infinity
# # P = P[P.posteriorProb!='-Infinity']
# print np.shape(P)

# X = P.groupby(['similarityMetric', 'speakerModel'])['logLikelihood']
# Y = X.apply(lambda x: reduce(sumlogprob,x) - np.log(len(x)))
# Y = pd.DataFrame(Y)

# sns.set_context('talk')
# colors = sns.color_palette("Paired")
# fig = plt.figure(figsize=(16,4))
# seq = [('strict-mid-pragmatics-augmented','S0'),('strict-mid-pragmatics-augmented','S1'),('strict-mid-pragmatics','S0'),('strict-mid-pragmatics','S1'),('nonstrict-high-sketchy','S0'),('nonstrict-high-sketchy','S1')]
# sns.barplot(data=Y.transpose(),palette=colors, order = seq)
# plt.ylim([-9000,-8000])
# plt.ylabel('log likelihood')
# plt.title('model comparison: held out data (majority far trials)',fontsize=24)
# plt.show()
